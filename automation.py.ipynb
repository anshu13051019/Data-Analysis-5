# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\Mall_Customers.csv")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df = df.drop_duplicates()
df = df.fillna(method="ffill")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11108\722699408.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")

# %%
df.to_csv(r"C:\Users\HP\Downloads\Cleaned_Mall_Customers.csv",index=False)

# %%
df.to_excel(r"C:\Users\HP\Downloads\Mall_Customers_Output.xlsx",index=False)

# %%
print("Automation completed successfully!")
# Out:
# Automation completed successfully!
